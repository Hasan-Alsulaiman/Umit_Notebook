# %%
import pandas as pd
import numpy as np
import random
import networkx as nx
from tqdm import tqdm
import re
import matplotlib.pyplot as plt
import json



from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
# load  details
with open("data (1).json") as f:
    data = json.load(f)

# %%
print(data['edges'][1]['source'])
# Out:
# MCM5

# %%
# captture nodes in 2 separate lists
node_list_1 = []
node_list_2 = []

# tqdm is just a progress bar, so this is a normal for loop with a progress bar.
for i in tqdm(data['edges']):
#     the links in fb_links are sperated by a comma, to split them into two lists we do:
   node_list_1.append((i['source']))
   node_list_2.append((i['target']))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 2000/2000 [00:00<00:00, 999119.58it/s]

# %%
print(node_list_2)
# Out:
# [' PTK2', ' UBA52', ' APC', ' NUDT5', ' BTF3', ' FANCD2', ' BIRC4', ' CACYBP', ' PRO1268', ' PSMD14', ' MYH10', ' TGFB1', ' FXR2', ' MGC10471', ' UBE3A', ' RUNX2', ' EIF2S1', ' RPL35A', ' RPL27A', ' CBX5', ' NID1', ' GLRX5', ' PDCD6IP', ' TARS', ' TXN', ' TAGLN2', ' TAF15', ' PTK7', ' PHKG1', ' RFX1', ' CREB1', ' CAPNS1', ' TAF7', ' SNRPB', ' POLR2I', ' TH1L', ' TXNL4A', ' MCM7', ' SRC', ' RPL8', ' RPSA', ' FAU', ' RPL30', ' EPOR', ' NRAS', ' ID4', ' COPG', ' HIST2H2BE', ' FN1', ' UBA52', ' SNRPF', ' NUP205', ' NOC4L', ' SNURF', ' DHX9', ' DHX38', ' HNRPF', ' SF3B5', ' SFRS5', ' COL1A1', ' PSMD8', ' EIF3S4', ' RPLP2', ' HSPA1B', ' TRAF2', ' HNRPU', ' CSTF1', ' ASCC2', ' MDS025', ' CSPG2', ' PSMD3', ' KIF5B', ' KRT18', ' RNPS1', ' TYK2', ' CD33', ' SEMA6D', ' C10ORF62', ' DDX19A', ' KIAA0415', ' RPSA', ' RPS23', ' EIF3S10', ' EIF3S2', ' HAP1', ' MYH11', ' LOC374443', ' C14ORF1', ' NCL', ' RPA1', ' PRKCA', ' C4A', ' MAPK12', ' IQGAP1', ' HNRPC', ' PARG', ' RPL9', ' EIF1AX', ' RXRA', ' PCNA', ' ATF7IP', ' PPFIA1', ' RPL9', ' RANBP1', ' TMEM33', ' HSP90AB1', ' CLTC', ' TPD52L2', ' MYL6', ' EEF1G', ' RPA3', ' PSEN2', ' RPL39', ' RPS23', ' RPL37', ' RPL17', ' RPLP1', ' MOV10', ' PDLIM1', ' GNG7', ' SF3B5', ' PLD1', ' CD5', ' DDX5', ' CHRNA2', ' NEDD4', ' WBSCR1', ' EIF4G1', ' FLJ22555', ' RPL35A', ' RPL3', ' RPL30', ' RPL26', ' BTF3', ' PSMD7', ' SART3', ' GTF2H4', ' RCP9', ' MEN1', ' HERC1', ' QARS', ' WWP1', ' ZFYVE9', ' EIF2S3', ' EIF3S10', ' EIF3S12', ' RPS15A', ' DPM2', ' HNRPD', ' TAF12', ' SNRPE', ' CTDP1', ' CPSF1', ' NUDT3', ' PTPN6', ' GPAM', ' SFRS1', ' LOC134147', ' EWSR1', ' IGHD', ' TJP1', ' HEXDC', ' UFM1', ' CA12', ' KHSRP', ' PRKACA', ' HSF1', ' TAF2', ' LOC255969', ' SAFB', ' CDC40', ' IRS1', ' CDKN1B', ' AKT1', ' RAB3D', ' TEK', ' ERBB3', ' ITGA6', ' MYOD1', ' EEF1G', ' SETD8', ' RPL35A', ' RPS3A', ' FAU', ' RPS6', ' ATM', ' POU2AF1', ' XRCC6', ' DHX38', ' RPL3', ' EIF2S2', ' MED10', ' SFRS9', ' CIB1', ' KPNA1', ' CAMK2G', ' ITGB1', ' MYOZ1', ' HSF1', ' ST3GAL2', ' COPS6', ' RPA2', ' UBA52', ' TRAF1', ' HSP90AA1', ' MOBK1B', ' SPTAN1', ' RAP2A', ' RNF138', ' CCND1', ' RPL38', ' RPSA', ' EIF4E', ' EIF4A2', ' EIF3S8', ' KIAA1446', ' CD2BP2', ' SNRPB', ' ERCC2', ' FXC1', ' PPP2CB', ' COL4A3', ' KIF3B', ' TCP1', ' KIF3C', ' FLJ44606', ' DCP1A', ' HNRPH1', ' NUMBL', ' IRF3', ' IRAK2', ' TCP1', ' PFN2', ' CTPS', ' ERH', ' RCC2', ' ERF', ' GNGT1', ' RHOB', ' EIF4A1', ' USHBP1', ' LCP2', ' CCNB1', ' CDCA8', ' AKAP4', ' TRAF1', ' RPS3', ' RPL7A', ' RPL27', ' RPL18', ' PRPF4', ' SNRPA', ' SFRS3', ' RPS6KA1', ' SIGLEC5', ' HNRPK', ' RPL3', ' GDI2', ' YWHAB', ' HCFC1', ' PPP1R3D', ' HNRPC', ' SNRPD1', ' PACSIN3', ' GRB2', ' TP53', ' SDC2', ' SIKE', ' RBL1', ' MAPK8', ' PAX8', ' UPF1', ' SMARCD2', ' RUNX2', ' SNRPA', ' HNRPF', ' F2RL2', ' TSC22D4', ' TRAF3', ' MRPS23', ' RPL23A', ' PPP2R2B', ' EIF4E', ' SSRP1', ' HNRPR', ' RPL38', ' RPL10A', ' VPS18', ' SRP72', ' RPS5', ' RPL23A', ' EP300', ' CASK', ' PRKCQ', ' RPL38', ' EIF4B', ' CBX4', ' RPA1', ' RPL37', ' PPP1CA', ' PPP1R11', ' GCG', ' TPR', ' ATP5C1', ' WEE1', ' CHEK1', ' HNRPL', ' YBX1', ' TAF1', ' UBADC1', ' RPL35A', ' MLH1', ' PCNA', ' RPL26L1', ' EIF4A2', ' HNRPH2', ' PACSIN3', ' USMG5', ' STAT3', ' DOK1', ' RPS5', ' RPL37A', ' DHODH', ' LPP', ' GRIN2A', ' EIF3S9', ' RPL7A', ' PDCD6IP', ' LOC285370', ' MTHFD1', ' CTNND1', ' NXF1', ' SETDB1', ' LASP1', ' C1ORF165', ' HNRPL', ' SF3A2', ' CDK7', ' GTF2H1', ' AP1M1', ' RPL5', ' UBR1', ' UBQLN4', ' EIF2B1', ' EIF2B3', ' MAFG', ' ESR2', ' E2F1', ' POLD2', ' EIF2AK2', ' ERBB3', ' CDKN1C', ' LIMK1', ' CFTR', ' CHUK', ' ACBD3', ' HABP4', ' MAPT', ' NCF4', ' RXRB', ' MMP9', ' SYT1', ' GATA5', ' PIAS3', ' CD4', ' FUBP1', ' ZNHIT1', ' TBC1D1', ' SQSTM1', ' ABTB1', ' CDK4', ' RPL8', ' PPP1R8', ' DMAP1', ' HMOX1', ' IQGAP1', ' PIN1', ' APOE', ' PKN2', ' YWHAH', ' RARA', ' RAB10', ' ZHX1', ' EFEMP2', ' YWHAZ', ' YY1AP1', ' ITGAV', ' CKS2', ' CTNNB1', ' FGR', ' NCOA3', ' POLR2G', ' SSRP1', ' CDC40', ' PPAT', ' EIF2S1', ' GDF8', ' INHB ...

# %%
data_df = pd.DataFrame({'node_1': node_list_1, 'node_2': node_list_2})

# %%
 data_df.head()
# Out:
#    node_1  node_2
# 0  TRIP6     PTK2
# 1   MCM5    UBA52
# 2   MCM5      APC
# 3  TRAF6    NUDT5
# 4  TRAF6     BTF3

# %%
# create graph
G = nx.from_pandas_edgelist(data_df, "node_1", "node_2", create_using=nx.Graph())
# plot graph
plt.figure(figsize=(10,10))

# pos = nx.random_layout(G, seed=23)
pos = nx.spring_layout(G)
d = dict(G.degree)
node_color = [20000.0 * G.degree(v) for v in G]
nx.draw(G, node_color=node_color, with_labels=False,  pos = pos, alpha = 0.6, width = 0.7, node_size=[v * 10 for v in d.values()])

plt.show()
